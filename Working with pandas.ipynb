# %%
# To load the pandas package and start working with it, import the package.
import pandas as pd
import numpy as np

# %%
# Manually store data in a table create a DataFrame.
# A DataFrame is a 2-dimensional data structure that can store data of different types (including characters, integers, floating point values, categorical data and more) in columns.
df = pd.DataFrame({
    "Name" : ["Shivam Sing",
              "Vivek Panday",
              "Raju Shrivastava",
              "Shreya Singh"],
     "Age" : [25,40,30,35],
    "Sex" : ["Male","Male","Male","Female"]              

})

# %%
df
# Out:
#                Name  Age     Sex
# 0       Shivam Sing   25    Male
# 1      Vivek Panday   40    Male
# 2  Raju Shrivastava   30    Male
# 3      Shreya Singh   35  Female

# %% [markdown]
# Data Selection

# %%
# Data Selection

# 1 Getitem ([]) -- For a DataFrame, passing a single label selects a columns

df["Name"]
# Out:
# 0         Shivam Sing
# 1        Vivek Panday
# 2    Raju Shrivastava
# 3        Shreya Singh
# Name: Name, dtype: object

# %%
# I’m just interested in working with the data in the column Age
# When selecting a single column of a pandas DataFrame, the result is a pandas Series. To select the column, use the column label in between square brackets [].
df["Name"]
# Out:
# 0         Shivam Sing
# 1        Vivek Panday
# 2    Raju Shrivastava
# 3        Shreya Singh
# Name: Name, dtype: object

# %%
# it is used to select the first row of a Pandas DataFrame.
df[0:1]
# Out:
#           Name  Age   Sex
# 0  Shivam Sing   25  Male

# %%
df[0:2]
# Out:
#            Name  Age   Sex
# 0   Shivam Sing   25  Male
# 1  Vivek Panday   40  Male

# %%
# 2  Selection by label
# See more in Selection by Label using DataFrame.loc() or DataFrame.at().
df.loc[1]
# Out:
# Name    Vivek Panday
# Age               40
# Sex             Male
# Name: 1, dtype: object

# %%
# retrieves the row where the index is 1.
df.loc[1]
# Out:
# Name    Vivek Panday
# Age               40
# Sex             Male
# Name: 1, dtype: object

# %%
df.loc[3]
# Out:
# Name    Shreya Singh
# Age               35
# Sex           Female
# Name: 3, dtype: object

# %%
print(df.loc[:, "Name"])
# Out:
# 0         Shivam Sing
# 1        Vivek Panday
# 2    Raju Shrivastava
# 3        Shreya Singh
# Name: Name, dtype: object

# %%
print(df.loc[df["Name"] == "Vivek Panday"])
# Out:
#            Name  Age   Sex
# 1  Vivek Panday   40  Male

# %%
# 3  Selection by position
# See more in Selection by Position using DataFrame.iloc() or DataFrame.iat().

# Select via the position of the passed integers:

df.iloc[3]
# Out:
# Name    Shreya Singh
# Age               35
# Sex           Female
# Name: 3, dtype: object

# %%
df.iloc[1:3, 0:2]
# Out:
#                Name  Age
# 1      Vivek Panday   40
# 2  Raju Shrivastava   30

# %%
# Boolean indexing
# Select rows where df.A is greater than 0
df[df["Age"] > 0]
# Out:
#                Name  Age     Sex
# 0       Shivam Sing   25    Male
# 1      Vivek Panday   40    Male
# 2  Raju Shrivastava   30    Male
# 3      Shreya Singh   35  Female

# %%
df[df["Age"]> 25]
# Out:
#                Name  Age     Sex
# 1      Vivek Panday   40    Male
# 2  Raju Shrivastava   30    Male
# 3      Shreya Singh   35  Female

# %%
# Adding a new column "Salary"
df["Salary"] = [50000, 60000, 55000, 70000]
df["Country"] = "India"  # Assigns "India" to all rows

# %%
df
# Out:
#                Name  Age     Sex  Salary Country
# 0       Shivam Sing   25    Male   50000   India
# 1      Vivek Panday   40    Male   60000   India
# 2  Raju Shrivastava   30    Male   55000   India
# 3      Shreya Singh   35  Female   70000   India

# %%
# I want to know the maximum Age
df["Age"].max()
# Out:
# 40

# %%
# I want to know the minmum Age
df["Age"].min()
# Out:
# 25

# %%
# some basic statistics of the numerical data of my data table
df["Age"].describe()
# Out:
# count     4.000000
# mean     32.500000
# std       6.454972
# min      25.000000
# 25%      28.750000
# 50%      32.500000
# 75%      36.250000
# max      40.000000
# Name: Age, dtype: float64

# %%
df.count()
# Out:
# Name       4
# Age        4
# Sex        4
# Salary     4
# Country    4
# dtype: int64

# %%
df.describe()
# Out:
#              Age        Salary
# count   4.000000      4.000000
# mean   32.500000  58750.000000
# std     6.454972   8539.125638
# min    25.000000  50000.000000
# 25%    28.750000  53750.000000
# 50%    32.500000  57500.000000
# 75%    36.250000  62500.000000
# max    40.000000  70000.000000

# %%
# Reading or Importing a CSV file into a pandas DataFrame
# read_file = pd.read_csv(r"C:\Users\HP\Downloads\sample_data.csv")
load_data = pd.read_csv("C:/Users/HP/Downloads/sampledata.csv")
load_data
# Out:
#    First Name Last Name   Age         City Country                    Email  \
# 0        John       Doe  25.0     New York     USA     john.doe@example.com
# 1       Alice     Smith  30.0  Los Angeles     USA  alice.smith@example.com
# 2         Bob   Johnson  28.0      Chicago     USA                      NaN
# 3        John       Doe  25.0     New York     USA     john.doe@example.com
# 4     Charlie     Brown   NaN      Houston     USA    charlie.b@example.com
# 5       Emily     Davis  35.0      Phoenix     USA                      NaN
# 6       Frank    Miller  40.0          NaN     USA      frank.m@example.com
# 7       Grace    Wilson  27.0    San Diego     USA      grace.w@example.com
# 8        Hank    Taylor   NaN       Dallas     USA       hank.t@example.com
# 9         Ivy  Martinez  29.0     San Jose     USA                      NaN
# 10       John       Doe  25.0     New York     USA     john.doe@example.com
# 11      Alice     Smith  30.0  Los Angeles     USA  alice.smith@example.com
# 12        Bob   Johnson  28.0      Chicago     USA                      NaN
# 13       John       Doe  25.0     New York     USA     john.doe@example.com
# 14    Charlie     Brown   NaN      Houston     USA    charlie.b@example.com
# 15      Emily     Davis  35.0      Phoenix     USA                      NaN
# 16      Frank    Miller  40.0          NaN     USA      frank.m@example.com
# 17      Grace    Wilson  27.0    San Diego     USA      grace.w@example.com
# 18       Hank    Taylor   NaN       Dallas     USA       hank.t@example.com
# 19        Ivy  Martinez  29.0     San Jose     USA                      NaN
# 20       Jake       Lee  33.0          NaN     USA       jake.l@example.com
# 21       Kara     White  31.0       Austin     USA                      NaN
# 22        Leo     Black  37.0      Seattle     USA        leo.b@example.com
#
#            Phone   Salary
# 0   123-456-7890  50000.0
# 1   987-654-3210  60000.0
# 2   555-666-7777  55000.0
# 3            NaN  50000.0
# 4   222-333-4444  52000.0
# 5   111-222-3333      NaN
# 6   999-888-7777  70000.0
# 7            NaN  62000.0
# 8   777-888-9999  58000.0
# 9   666-555-4444  61000.0
# 10  123-456-7890  50000.0
# 11  987-654-3210  60000.0
# 12  555-666-7777  55000.0
# 13           NaN  50000.0
# 14  222-333-4444  52000.0
# 15  111-222-3333      NaN
# 16  999-888-7777  70000.0
# 17           NaN  62000.0
# 18  777-888-9999  58000.0
# 19  666-555-4444  61000.0
# 20  444-555-6666  59000.0
# 21  333-222-1111      NaN
# 22  888-777-6666  68000.0

# %% [markdown]
# working with missing Data

# %%
# working with missing Data
# In pandas, missing data is represented by NaN (Not a Number), which comes from NumPy (np.nan). 
# By default, pandas ignores NaN values in computations but provides various methods to handle them.
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data:

# %%
load_data.isnull().sum()
# Out:
# First Name    0
# Last Name     0
# Age           4
# City          3
# Country       0
# Email         7
# Phone         4
# Salary        3
# dtype: int64

# %%
load_data.isna()
# Out:
#     First Name  Last Name    Age   City  Country  Email  Phone  Salary
# 0        False      False  False  False    False  False  False   False
# 1        False      False  False  False    False  False  False   False
# 2        False      False  False  False    False   True  False   False
# 3        False      False  False  False    False  False   True   False
# 4        False      False   True  False    False  False  False   False
# 5        False      False  False  False    False   True  False    True
# 6        False      False  False   True    False  False  False   False
# 7        False      False  False  False    False  False   True   False
# 8        False      False   True  False    False  False  False   False
# 9        False      False  False  False    False   True  False   False
# 10       False      False  False  False    False  False  False   False
# 11       False      False  False  False    False  False  False   False
# 12       False      False  False  False    False   True  False   False
# 13       False      False  False  False    False  False   True   False
# 14       False      False   True  False    False  False  False   False
# 15       False      False  False  False    False   True  False    True
# 16       False      False  False   True    False  False  False   False
# 17       False      False  False  False    False  False   True   False
# 18       False      False   True  False    False  False  False   False
# 19       False      False  False  False    False   True  False   False
# 20       False      False  False   True    False  False  False   False
# 21       False      False  False  False    False   True  False    True
# 22       False      False  False  False    False  False  False   False

# %%
load_data.fillna(27)
# Out:
#    First Name Last Name   Age         City Country                    Email  \
# 0        John       Doe  25.0     New York     USA     john.doe@example.com
# 1       Alice     Smith  30.0  Los Angeles     USA  alice.smith@example.com
# 2         Bob   Johnson  28.0      Chicago     USA                       27
# 3        John       Doe  25.0     New York     USA     john.doe@example.com
# 4     Charlie     Brown  27.0      Houston     USA    charlie.b@example.com
# 5       Emily     Davis  35.0      Phoenix     USA                       27
# 6       Frank    Miller  40.0           27     USA      frank.m@example.com
# 7       Grace    Wilson  27.0    San Diego     USA      grace.w@example.com
# 8        Hank    Taylor  27.0       Dallas     USA       hank.t@example.com
# 9         Ivy  Martinez  29.0     San Jose     USA                       27
# 10       John       Doe  25.0     New York     USA     john.doe@example.com
# 11      Alice     Smith  30.0  Los Angeles     USA  alice.smith@example.com
# 12        Bob   Johnson  28.0      Chicago     USA                       27
# 13       John       Doe  25.0     New York     USA     john.doe@example.com
# 14    Charlie     Brown  27.0      Houston     USA    charlie.b@example.com
# 15      Emily     Davis  35.0      Phoenix     USA                       27
# 16      Frank    Miller  40.0           27     USA      frank.m@example.com
# 17      Grace    Wilson  27.0    San Diego     USA      grace.w@example.com
# 18       Hank    Taylor  27.0       Dallas     USA       hank.t@example.com
# 19        Ivy  Martinez  29.0     San Jose     USA                       27
# 20       Jake       Lee  33.0           27     USA       jake.l@example.com
# 21       Kara     White  31.0       Austin     USA                       27
# 22        Leo     Black  37.0      Seattle     USA        leo.b@example.com
#
#            Phone   Salary
# 0   123-456-7890  50000.0
# 1   987-654-3210  60000.0
# 2   555-666-7777  55000.0
# 3             27  50000.0
# 4   222-333-4444  52000.0
# 5   111-222-3333     27.0
# 6   999-888-7777  70000.0
# 7             27  62000.0
# 8   777-888-9999  58000.0
# 9   666-555-4444  61000.0
# 10  123-456-7890  50000.0
# 11  987-654-3210  60000.0
# 12  555-666-7777  55000.0
# 13            27  50000.0
# 14  222-333-4444  52000.0
# 15  111-222-3333     27.0
# 16  999-888-7777  70000.0
# 17            27  62000.0
# 18  777-888-9999  58000.0
# 19  666-555-4444  61000.0
# 20  444-555-6666  59000.0
# 21  333-222-1111     27.0
# 22  888-777-6666  68000.0

# %%
load_data["Age"].fillna(method='ffill')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10952\3188212920.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   load_data["Age"].fillna(method='ffill')
# 0     25.0
# 1     30.0
# 2     28.0
# 3     25.0
# 4     25.0
# 5     35.0
# 6     40.0
# 7     27.0
# 8     27.0
# 9     29.0
# 10    25.0
# 11    30.0
# 12    28.0
# 13    25.0
# 14    25.0
# 15    35.0
# 16    40.0
# 17    27.0
# 18    27.0
# 19    29.0
# 20    33.0
# 21    31.0
# 22    37.0
# Name: Age, dtype: float64

# %%
load_data.fillna(method='bfill')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10952\3175916046.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   load_data.fillna(method='bfill')
#    First Name Last Name   Age         City Country                    Email  \
# 0        John       Doe  25.0     New York     USA     john.doe@example.com
# 1       Alice     Smith  30.0  Los Angeles     USA  alice.smith@example.com
# 2         Bob   Johnson  28.0      Chicago     USA     john.doe@example.com
# 3        John       Doe  25.0     New York     USA     john.doe@example.com
# 4     Charlie     Brown  35.0      Houston     USA    charlie.b@example.com
# 5       Emily     Davis  35.0      Phoenix     USA      frank.m@example.com
# 6       Frank    Miller  40.0    San Diego     USA      frank.m@example.com
# 7       Grace    Wilson  27.0    San Diego     USA      grace.w@example.com
# 8        Hank    Taylor  29.0       Dallas     USA       hank.t@example.com
# 9         Ivy  Martinez  29.0     San Jose     USA     john.doe@example.com
# 10       John       Doe  25.0     New York     USA     john.doe@example.com
# 11      Alice     Smith  30.0  Los Angeles     USA  alice.smith@example.com
# 12        Bob   Johnson  28.0      Chicago     USA     john.doe@example.com
# 13       John       Doe  25.0     New York     USA     john.doe@example.com
# 14    Charlie     Brown  35.0      Houston     USA    charlie.b@example.com
# 15      Emily     Davis  35.0      Phoenix     USA      frank.m@example.com
# 16      Frank    Miller  40.0    San Diego     USA      frank.m@example.com
# 17      Grace    Wilson  27.0    San Diego     USA      grace.w@example.com
# 18       Hank    Taylor  29.0       Dallas     USA       hank.t@example.com
# 19        Ivy  Martinez  29.0     San Jose     USA       jake.l@example.com
# 20       Jake       Lee  33.0       Austin     USA       jake.l@example.com
# 21       Kara     White  31.0       Austin     USA        leo.b@example.com
# 22        Leo     Black  37.0      Seattle     USA        leo.b@example.com
#
#            Phone   Salary
# 0   123-456-7890  50000.0
# 1   987-654-3210  60000.0
# 2   555-666-7777  55000.0
# 3   222-333-4444  50000.0
# 4   222-333-4444  52000.0
# 5   111-222-3333  70000.0
# 6   999-888-7777  70000.0
# 7   777-888-9999  62000.0
# 8   777-888-9999  58000.0
# 9   666-555-4444  61000.0
# 10  123-456-7890  50000.0
# 11  987-654-3210  60000.0
# 12  555-666-7777  55000.0
# 13  222-333-4444  50000.0
# 14  222-333-4444  52000.0
# 15  111-222-3333  70000.0
# 16  999-888-7777  70000.0
# 17  777-888-9999  62000.0
# 18  777-888-9999  58000.0
# 19  666-555-4444  61000.0
# 20  444-555-6666  59000.0
# 21  333-222-1111  68000.0
# 22  888-777-6666  68000.0

# %%
load_data.interpolate()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10952\2306698119.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   load_data.interpolate()
#    First Name Last Name   Age         City Country                    Email  \
# 0        John       Doe  25.0     New York     USA     john.doe@example.com
# 1       Alice     Smith  30.0  Los Angeles     USA  alice.smith@example.com
# 2         Bob   Johnson  28.0      Chicago     USA                      NaN
# 3        John       Doe  25.0     New York     USA     john.doe@example.com
# 4     Charlie     Brown  30.0      Houston     USA    charlie.b@example.com
# 5       Emily     Davis  35.0      Phoenix     USA                      NaN
# 6       Frank    Miller  40.0          NaN     USA      frank.m@example.com
# 7       Grace    Wilson  27.0    San Diego     USA      grace.w@example.com
# 8        Hank    Taylor  28.0       Dallas     USA       hank.t@example.com
# 9         Ivy  Martinez  29.0     San Jose     USA                      NaN
# 10       John       Doe  25.0     New York     USA     john.doe@example.com
# 11      Alice     Smith  30.0  Los Angeles     USA  alice.smith@example.com
# 12        Bob   Johnson  28.0      Chicago     USA                      NaN
# 13       John       Doe  25.0     New York     USA     john.doe@example.com
# 14    Charlie     Brown  30.0      Houston     USA    charlie.b@example.com
# 15      Emily     Davis  35.0      Phoenix     USA                      NaN
# 16      Frank    Miller  40.0          NaN     USA      frank.m@example.com
# 17      Grace    Wilson  27.0    San Diego     USA      grace.w@example.com
# 18       Hank    Taylor  28.0       Dallas     USA       hank.t@example.com
# 19        Ivy  Martinez  29.0     San Jose     USA                      NaN
# 20       Jake       Lee  33.0          NaN     USA       jake.l@example.com
# 21       Kara     White  31.0       Austin     USA                      NaN
# 22        Leo     Black  37.0      Seattle     USA        leo.b@example.com
#
#            Phone   Salary
# 0   123-456-7890  50000.0
# 1   987-654-3210  60000.0
# 2   555-666-7777  55000.0
# 3            NaN  50000.0
# 4   222-333-4444  52000.0
# 5   111-222-3333  61000.0
# 6   999-888-7777  70000.0
# 7            NaN  62000.0
# 8   777-888-9999  58000.0
# 9   666-555-4444  61000.0
# 10  123-456-7890  50000.0
# 11  987-654-3210  60000.0
# 12  555-666-7777  55000.0
# 13           NaN  50000.0
# 14  222-333-4444  52000.0
# 15  111-222-3333  61000.0
# 16  999-888-7777  70000.0
# 17           NaN  62000.0
# 18  777-888-9999  58000.0
# 19  666-555-4444  61000.0
# 20  444-555-6666  59000.0
# 21  333-222-1111  63500.0
# 22  888-777-6666  68000.0

# %%
pd.isna
# Out:
# <function pandas.core.dtypes.missing.isna(obj: 'object') -> 'bool | npt.NDArray[np.bool_] | NDFrame'>

# %%
# retrive all the column from the datafream
df.columns
# Out:
# Index(['Name', 'Age', 'Sex', 'Salary', 'Country'], dtype='object')

# %%
# converting data fream obj to list
df1 = list(df.columns)
df1
# Out:
# ['Name', 'Age', 'Sex', 'Salary', 'Country']

# %%
Name = df['Name']

# %%
df1 = df.reindex(index=Name[0:5])  
df1
# Out:
#                  Name  Age  Sex
# Name
# Shivam Sing       NaN  NaN  NaN
# Vivek Panday      NaN  NaN  NaN
# Raju Shrivastava  NaN  NaN  NaN
# Shreya Singh      NaN  NaN  NaN

# %%
df
# Out:
#                Name  Age     Sex
# 0       Shivam Sing   25    Male
# 1      Vivek Panday   40    Male
# 2  Raju Shrivastava   30    Male
# 3      Shreya Singh   35  Female

# %%
read_file.columns
# Out:
# Index(['Book_ID', 'Title', 'Author', 'Genre', 'Published_Year', 'Price',
#        'Stock'],
#       dtype='object')

# %%
data = {'A': [10, 20, 30, 40], 'B': [50, 60, 70, 80]}

# Creating a DataFrame 'dfx' using the data dictionary  
# The index parameter provides custom labels for the rows of the DataFrame  
# Here, the rows are labeled as 'row1', 'row2', 'row3', and 'row4'  
dfx = pd.DataFrame(data, index=['row1', 'row2', 'row3', 'row4'])
dfx
# Out:
#        A   B
# row1  10  50
# row2  20  60
# row2  30  70
# row3  40  80

# %%
  Author = read_file['Author']
Author
# Out:
# 0             Joseph Crane
# 1              Mario Moore
# 2           Derrick Howard
# 3      Christopher Andrews
# 4              Juan Miller
#               ...
# 495            James Adams
# 496         Craig Thompson
# 497          Heather Marks
# 498           Isaac Nelson
# 499         David Hatfield
# Name: Author, Length: 500, dtype: object

# %%
df2= df.reindex(index= Author[0:5])
df2
# Out:
#                     Name  Age  Sex
# Author
# Joseph Crane         NaN  NaN  NaN
# Mario Moore          NaN  NaN  NaN
# Derrick Howard       NaN  NaN  NaN
# Christopher Andrews  NaN  NaN  NaN
# Juan Miller          NaN  NaN  NaN

# %%
# Reading or Importing a CSV file into a pandas DataFrame
read_file0 = pd.read_csv(r"C:\Users\HP\Downloads\sales_data.csv", usecols = ["ORDERNUMBER"])

# %%
read_file0
# Out:
#       ORDERNUMBER
# 0           10107
# 1           10121
# 2           10134
# 3           10145
# 4           10159
# ...           ...
# 2818        10350
# 2819        10373
# 2820        10386
# 2821        10397
# 2822        10414
#
# [2823 rows x 1 columns]

# %%
# observe the output there is no header 
read_file1 = pd.read_csv(r"C:\Users\HP\Downloads\sales_data.csv", header =None)

# %%
read_file1
# Out:
#                0                1          2                3        4   \
# 0     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES
# 1           10107               30       95.7                2   2871.0
# 2           10121               34      81.35                5   2765.9
# 3           10134               41      94.74                2  3884.34
# 4           10145               45      83.26                6   3746.7
# ...           ...              ...        ...              ...      ...
# 2819        10350               20      100.0               15   2244.4
# 2820        10373               29      100.0                1  3978.51
# 2821        10386               43      100.0                4  5417.57
# 2822        10397               34      62.24                1  2116.16
# 2823        10414               47      65.52                9  3079.44
#
#               5         6       7         8        9   ...       18  \
# 0      ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...    STATE
# 1     2003-02-24   Shipped       1         2     2003  ...       NY
# 2     2003-05-07   Shipped       2         5     2003  ...  Unknown
# 3     2003-07-01   Shipped       3         7     2003  ...  Unknown
# 4     2003-08-25   Shipped       3         8     2003  ...       CA
# ...          ...       ...     ...       ...      ...  ...      ...
# 2819  2004-12-02   Shipped       4        12     2004  ...  Unknown
# 2820  2005-01-31   Shipped       1         1     2005  ...  Unknown
# 2821  2005-03-01  Resolved       1         3     2005  ...  Unknown
# 2822  2005-03-28   Shipped       1         3     2005  ...  Unknown
# 2823  2005-05-06   On Hold       2         5     2005  ...       MA
#
#               19       20         21               22                23  \
# 0     POSTALCODE  COUNTRY  TERRITORY  CONTACTLASTNAME  CONTACTFIRSTNAME
# 1          10022      USA    Unknown               Yu              Kwai
# 2          51100   France       EMEA          Henriot              Paul
# 3          75508   France       EMEA         Da Cunha            Daniel
# 4          90003      USA    Unknown            Young             Julie
# ...          ...      ...        ...              ...               ...
# 2819       28034    Spain       EMEA           Freyre             Diego
# 2820       90110  Finland       EMEA        Koskitalo            Pirkko
# 2821       28034    Spain       EMEA           Freyre             Diego
# 2822       31000   France       EMEA           Roulet           Annette
# 2823       51003      USA    Unknown          Yoshido              Juri
#
#             24          25           26         27
# 0     DEALSIZE  ORDER_YEAR  ORDER_MONTH  ORDER_DAY
# 1        Small        2003            2         24
# 2        Small        2003            5          7
# 3       Medium        2003            7          1
# 4       Medium        2003            8         25
# ...        ...         ...          ...        ...
# 2819     Small        2004           12          2
# 2820    Medium        2005            1         31
# 2821    Medium        2005            3          1
# 2822     Small        2005            3         28
# 2823    Medium        2005            5          6
#
# [2824 rows x 28 columns]

# %%
# observe the output there is custom header 
read_filek2 = pd.read_csv(r"C:\Users\HP\Downloads\sales_data.csv", names = [ "q_order", "q_number", "price", "bhv", "bihg", 
    "col_5", "col_8", "col_3", "col_9", "col_2", 
    "col_45", "col_26", "col_35", "col_25", "bvib", 
    "nbjib", "col_5_dup", "col_6", "col_85", "col_25_dup", 
    "col_52", "col_65", "col_25_dup2"], header = None)

# %%
read_filek2
# Out:
#                                                                   q_order  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES     ORDERDATE
# 10107       30              95.7      2               2871.0   2003-02-24
# 10121       34              81.35     5               2765.9   2003-05-07
# 10134       41              94.74     2               3884.34  2003-07-01
# 10145       45              83.26     6               3746.7   2003-08-25
# ...                                                                   ...
# 10350       20              100.0     15              2244.4   2004-12-02
# 10373       29              100.0     1               3978.51  2005-01-31
# 10386       43              100.0     4               5417.57  2005-03-01
# 10397       34              62.24     1               2116.16  2005-03-28
# 10414       47              65.52     9               3079.44  2005-05-06
#
#                                                                q_number  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES      STATUS
# 10107       30              95.7      2               2871.0    Shipped
# 10121       34              81.35     5               2765.9    Shipped
# 10134       41              94.74     2               3884.34   Shipped
# 10145       45              83.26     6               3746.7    Shipped
# ...                                                                 ...
# 10350       20              100.0     15              2244.4    Shipped
# 10373       29              100.0     1               3978.51   Shipped
# 10386       43              100.0     4               5417.57  Resolved
# 10397       34              62.24     1               2116.16   Shipped
# 10414       47              65.52     9               3079.44   On Hold
#
#                                                                 price  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    QTR_ID
# 10107       30              95.7      2               2871.0        1
# 10121       34              81.35     5               2765.9        2
# 10134       41              94.74     2               3884.34       3
# 10145       45              83.26     6               3746.7        3
# ...                                                               ...
# 10350       20              100.0     15              2244.4        4
# 10373       29              100.0     1               3978.51       1
# 10386       43              100.0     4               5417.57       1
# 10397       34              62.24     1               2116.16       1
# 10414       47              65.52     9               3079.44       2
#
#                                                                     bhv  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    MONTH_ID
# 10107       30              95.7      2               2871.0          2
# 10121       34              81.35     5               2765.9          5
# 10134       41              94.74     2               3884.34         7
# 10145       45              83.26     6               3746.7          8
# ...                                                                 ...
# 10350       20              100.0     15              2244.4         12
# 10373       29              100.0     1               3978.51         1
# 10386       43              100.0     4               5417.57         3
# 10397       34              62.24     1               2116.16         3
# 10414       47              65.52     9               3079.44         5
#
#                                                                   bihg  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    YEAR_ID
# 10107       30              95.7      2               2871.0      2003
# 10121       34              81.35     5               2765.9      2003
# 10134       41              94.74     2               3884.34     2003
# 10145       45              83.26     6               3746.7      2003
# ...                                                                ...
# 10350       20              100.0     15              2244.4      2004
# 10373       29              100.0     1               3978.51     2005
# 10386       43              100.0     4               5417.57     2005
# 10397       34              62.24     1               2116.16     2005
# 10414       47              65.52     9               3079.44     2005
#
#                                                                      col_5  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    PRODUCTLINE
# 10107       30              95.7      2               2871.0   Motorcycles
# 10121       34              81.35     5               2765.9   Motorcycles
# 10134       41              94.74     2               3884.34  Motorcycles
# 10145       45              83.26     6               3746.7   Motorcycles
# ...                                                                    ...
# 10350       20              100.0     15              2244.4         Ships
# 10373       29              100.0     1               3978.51        Ships
# 10386       43              100.0     4               5417.57        Ships
# 10397       34              62.24     1               2116.16        Ships
# 10414       47              65.52     9               3079.44        Ships
#
#                                                               col_8  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    MSRP
# 10107       30              95.7      2               2871.0     95
# 10121       34              81.35     5               2765.9     95
# 10134       41              94.74     2               3884.34    95
# 10145       45              83.26     6               3746.7     95
# ...                                                             ...
# 10350       20              100.0     15              2244.4     54
# 10373       29              100.0     1               3978.51    54
# 10386       43              100.0     4               5417.57    54
# 10397       34              62.24     1               2116.16    54
# 10414       47              65.52     9               3079.44    54
#
#                                                                      col_3  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    PRODUCTCODE
# 10107       30              95.7      2               2871.0      S10_1678
# 10121       34              81.35     5               2765.9      S10_1678
# 10134       41              94.74     2               3884.34     S10_1678
# 10145       45              83.26     6               3746.7      S10_1678
# ...                                                                    ...
# 10350       20              100.0     15              2244.4      S72_3212
# 10373       29              100.0     1               3978.51     S72_3212
# 10386       43              100.0     4               5417.57     S72_3212
# 10397       34              62.24     1               2116.16     S72_3212
# 10414       47              65.52     9               3079.44     S72_3212
#
#                                                                                  col_9  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES               CUSTOMERNAME
# 10107       30              95.7      2               2871.0         Land of Toys Inc.
# 10121       34              81.35     5               2765.9        Reims Collectables
# 10134       41              94.74     2               3884.34          Lyon Souveniers
# 10145       45              83.26     6               3746.7         Toys4GrownUps.com
# ...                                                                                ...
# 10350       20              100.0     15              2244.4     Euro Shopping Channel
# 10373       29              100.0     1               3978.51  Oulu Toy Supplies, Inc.
# 10386       43              100.0     4               5417.57    Euro Shopping Channel
# 10397       34              62.24     1               2116.16             Alpha Cognac
# 10414       47              65.52     9               3079.44        Gifts4AllAges.com
#
#                                                                           col_2  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES               PHONE
# 10107       30              95.7      2               2871.0         2125557818
# 10121       34              81.35     5               2765.9         26.47.1555
# 10134       41              94.74     2               3884.34  +33 1 46 62 7555
# 10145       45              83.26     6               3746.7         6265557265
# ...                                                                         ...
# 10350       20              100.0     15              2244.4     (91) 555 94 44
# 10373       29              100.0     1               3978.51        981-443655
# 10386       43              100.0     4               5417.57    (91) 555 94 44
# 10397       34              62.24     1               2116.16        61.77.6555
# 10414       47              65.52     9               3079.44        6175559555
#
#                                                                ...   col_25  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    ...    STATE
# 10107       30              95.7      2               2871.0   ...       NY
# 10121       34              81.35     5               2765.9   ...  Unknown
# 10134       41              94.74     2               3884.34  ...  Unknown
# 10145       45              83.26     6               3746.7   ...       CA
# ...                                                            ...      ...
# 10350       20              100.0     15              2244.4   ...  Unknown
# 10373       29              100.0     1               3978.51  ...  Unknown
# 10386       43              100.0     4               5417.57  ...  Unknown
# 10397       34              62.24     1               2116.16  ...  Unknown
# 10414       47              65.52     9               3079.44  ...       MA
#
#                                                                      bvib  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    POSTALCODE
# 10107       30              95.7      2               2871.0        10022
# 10121       34              81.35     5               2765.9        51100
# 10134       41              94.74     2               3884.34       75508
# 10145       45              83.26     6               3746.7        90003
# ...                                                                   ...
# 10350       20              100.0     15              2244.4        28034
# 10373       29              100.0     1               3978.51       90110
# 10386       43              100.0     4               5417.57       28034
# 10397       34              62.24     1               2116.16       31000
# 10414       47              65.52     9               3079.44       51003
#
#                                                                  nbjib  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    COUNTRY
# 10107       30              95.7      2               2871.0       USA
# 10121       34              81.35     5               2765.9    France
# 10134       41              94.74     2               3884.34   France
# 10145       45              83.26     6               3746.7       USA
# ...                                                                ...
# 10350       20              100.0     15              2244.4     Spain
# 10373       29              100.0     1               3978.51  Finland
# 10386       43              100.0     4               5417.57    Spain
# 10397       34              62.24     1               2116.16   France
# 10414       47              65.52     9               3079.44      USA
#
#                                                                col_5_dup  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    TERRITORY
# 10107       30              95.7      2               2871.0     Unknown
# 10121       34              81.35     5               2765.9        EMEA
# 10134       41              94.74     2               3884.34       EMEA
# 10145       45              83.26     6               3746.7     Unknown
# ...                                                                  ...
# 10350       20              100.0     15              2244.4        EMEA
# 10373       29              100.0     1               3978.51       EMEA
# 10386       43              100.0     4               5417.57       EMEA
# 10397       34              62.24     1               2116.16       EMEA
# 10414       47              65.52     9               3079.44    Unknown
#
#                                                                          col_6  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    CONTACTLASTNAME
# 10107       30              95.7      2               2871.0                Yu
# 10121       34              81.35     5               2765.9           Henriot
# 10134       41              94.74     2               3884.34         Da Cunha
# 10145       45              83.26     6               3746.7             Young
# ...                                                                        ...
# 10350       20              100.0     15              2244.4            Freyre
# 10373       29              100.0     1               3978.51        Koskitalo
# 10386       43              100.0     4               5417.57           Freyre
# 10397       34              62.24     1               2116.16           Roulet
# 10414       47              65.52     9               3079.44          Yoshido
#
#                                                                          col_85  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    CONTACTFIRSTNAME
# 10107       30              95.7      2               2871.0               Kwai
# 10121       34              81.35     5               2765.9               Paul
# 10134       41              94.74     2               3884.34            Daniel
# 10145       45              83.26     6               3746.7              Julie
# ...                                                                         ...
# 10350       20              100.0     15              2244.4              Diego
# 10373       29              100.0     1               3978.51            Pirkko
# 10386       43              100.0     4               5417.57             Diego
# 10397       34              62.24     1               2116.16           Annette
# 10414       47              65.52     9               3079.44              Juri
#
#                                                               col_25_dup  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES     DEALSIZE
# 10107       30              95.7      2               2871.0       Small
# 10121       34              81.35     5               2765.9       Small
# 10134       41              94.74     2               3884.34     Medium
# 10145       45              83.26     6               3746.7      Medium
# ...                                                                  ...
# 10350       20              100.0     15              2244.4       Small
# 10373       29              100.0     1               3978.51     Medium
# 10386       43              100.0     4               5417.57     Medium
# 10397       34              62.24     1               2116.16      Small
# 10414       47              65.52     9               3079.44     Medium
#
#                                                                    col_52  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    ORDER_YEAR
# 10107       30              95.7      2               2871.0         2003
# 10121       34              81.35     5               2765.9         2003
# 10134       41              94.74     2               3884.34        2003
# 10145       45              83.26     6               3746.7         2003
# ...                                                                   ...
# 10350       20              100.0     15              2244.4         2004
# 10373       29              100.0     1               3978.51        2005
# 10386       43              100.0     4               5417.57        2005
# 10397       34              62.24     1               2116.16        2005
# 10414       47              65.52     9               3079.44        2005
#
#                                                                     col_65  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    ORDER_MONTH
# 10107       30              95.7      2               2871.0             2
# 10121       34              81.35     5               2765.9             5
# 10134       41              94.74     2               3884.34            7
# 10145       45              83.26     6               3746.7             8
# ...                                                                    ...
# 10350       20              100.0     15              2244.4            12
# 10373       29              100.0     1               3978.51            1
# 10386       43              100.0     4               5417.57            3
# 10397       34              62.24     1               2116.16            3
# 10414       47              65.52     9               3079.44            5
#
#                                                               col_25_dup2
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES     ORDER_DAY
# 10107       30              95.7      2               2871.0           24
# 10121       34              81.35     5               2765.9            7
# 10134       41              94.74     2               3884.34           1
# 10145       45              83.26     6               3746.7           25
# ...                                                                   ...
# 10350       20              100.0     15              2244.4            2
# 10373       29              100.0     1               3978.51          31
# 10386       43              100.0     4               5417.57           1
# 10397       34              62.24     1               2116.16          28
# 10414       47              65.52     9               3079.44           6
#
# [2824 rows x 23 columns]

# %%
# Define proper column names
column_names = [
    "q_order", "q_number", "price", "bhv", "bihg", 
    "col_5", "col_8", "col_3", "col_9", "col_2", 
    "col_45", "col_26", "col_35", "col_25", "bvib", 
    "nbjib", "col_5_dup", "col_6", "col_85", "col_25_dup", 
    "col_52", "col_65", "col_25_dup2"
]

# Read CSV with custom headers
read_file3 = pd.read_csv(r"C:\Users\HP\Downloads\sales_data.csv", names=column_names, header=None)


read_file3
# Out:
#                                                                   q_order  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES     ORDERDATE
# 10107       30              95.7      2               2871.0   2003-02-24
# 10121       34              81.35     5               2765.9   2003-05-07
# 10134       41              94.74     2               3884.34  2003-07-01
# 10145       45              83.26     6               3746.7   2003-08-25
# ...                                                                   ...
# 10350       20              100.0     15              2244.4   2004-12-02
# 10373       29              100.0     1               3978.51  2005-01-31
# 10386       43              100.0     4               5417.57  2005-03-01
# 10397       34              62.24     1               2116.16  2005-03-28
# 10414       47              65.52     9               3079.44  2005-05-06
#
#                                                                q_number  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES      STATUS
# 10107       30              95.7      2               2871.0    Shipped
# 10121       34              81.35     5               2765.9    Shipped
# 10134       41              94.74     2               3884.34   Shipped
# 10145       45              83.26     6               3746.7    Shipped
# ...                                                                 ...
# 10350       20              100.0     15              2244.4    Shipped
# 10373       29              100.0     1               3978.51   Shipped
# 10386       43              100.0     4               5417.57  Resolved
# 10397       34              62.24     1               2116.16   Shipped
# 10414       47              65.52     9               3079.44   On Hold
#
#                                                                 price  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    QTR_ID
# 10107       30              95.7      2               2871.0        1
# 10121       34              81.35     5               2765.9        2
# 10134       41              94.74     2               3884.34       3
# 10145       45              83.26     6               3746.7        3
# ...                                                               ...
# 10350       20              100.0     15              2244.4        4
# 10373       29              100.0     1               3978.51       1
# 10386       43              100.0     4               5417.57       1
# 10397       34              62.24     1               2116.16       1
# 10414       47              65.52     9               3079.44       2
#
#                                                                     bhv  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    MONTH_ID
# 10107       30              95.7      2               2871.0          2
# 10121       34              81.35     5               2765.9          5
# 10134       41              94.74     2               3884.34         7
# 10145       45              83.26     6               3746.7          8
# ...                                                                 ...
# 10350       20              100.0     15              2244.4         12
# 10373       29              100.0     1               3978.51         1
# 10386       43              100.0     4               5417.57         3
# 10397       34              62.24     1               2116.16         3
# 10414       47              65.52     9               3079.44         5
#
#                                                                   bihg  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    YEAR_ID
# 10107       30              95.7      2               2871.0      2003
# 10121       34              81.35     5               2765.9      2003
# 10134       41              94.74     2               3884.34     2003
# 10145       45              83.26     6               3746.7      2003
# ...                                                                ...
# 10350       20              100.0     15              2244.4      2004
# 10373       29              100.0     1               3978.51     2005
# 10386       43              100.0     4               5417.57     2005
# 10397       34              62.24     1               2116.16     2005
# 10414       47              65.52     9               3079.44     2005
#
#                                                                      col_5  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    PRODUCTLINE
# 10107       30              95.7      2               2871.0   Motorcycles
# 10121       34              81.35     5               2765.9   Motorcycles
# 10134       41              94.74     2               3884.34  Motorcycles
# 10145       45              83.26     6               3746.7   Motorcycles
# ...                                                                    ...
# 10350       20              100.0     15              2244.4         Ships
# 10373       29              100.0     1               3978.51        Ships
# 10386       43              100.0     4               5417.57        Ships
# 10397       34              62.24     1               2116.16        Ships
# 10414       47              65.52     9               3079.44        Ships
#
#                                                               col_8  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    MSRP
# 10107       30              95.7      2               2871.0     95
# 10121       34              81.35     5               2765.9     95
# 10134       41              94.74     2               3884.34    95
# 10145       45              83.26     6               3746.7     95
# ...                                                             ...
# 10350       20              100.0     15              2244.4     54
# 10373       29              100.0     1               3978.51    54
# 10386       43              100.0     4               5417.57    54
# 10397       34              62.24     1               2116.16    54
# 10414       47              65.52     9               3079.44    54
#
#                                                                      col_3  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    PRODUCTCODE
# 10107       30              95.7      2               2871.0      S10_1678
# 10121       34              81.35     5               2765.9      S10_1678
# 10134       41              94.74     2               3884.34     S10_1678
# 10145       45              83.26     6               3746.7      S10_1678
# ...                                                                    ...
# 10350       20              100.0     15              2244.4      S72_3212
# 10373       29              100.0     1               3978.51     S72_3212
# 10386       43              100.0     4               5417.57     S72_3212
# 10397       34              62.24     1               2116.16     S72_3212
# 10414       47              65.52     9               3079.44     S72_3212
#
#                                                                                  col_9  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES               CUSTOMERNAME
# 10107       30              95.7      2               2871.0         Land of Toys Inc.
# 10121       34              81.35     5               2765.9        Reims Collectables
# 10134       41              94.74     2               3884.34          Lyon Souveniers
# 10145       45              83.26     6               3746.7         Toys4GrownUps.com
# ...                                                                                ...
# 10350       20              100.0     15              2244.4     Euro Shopping Channel
# 10373       29              100.0     1               3978.51  Oulu Toy Supplies, Inc.
# 10386       43              100.0     4               5417.57    Euro Shopping Channel
# 10397       34              62.24     1               2116.16             Alpha Cognac
# 10414       47              65.52     9               3079.44        Gifts4AllAges.com
#
#                                                                           col_2  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES               PHONE
# 10107       30              95.7      2               2871.0         2125557818
# 10121       34              81.35     5               2765.9         26.47.1555
# 10134       41              94.74     2               3884.34  +33 1 46 62 7555
# 10145       45              83.26     6               3746.7         6265557265
# ...                                                                         ...
# 10350       20              100.0     15              2244.4     (91) 555 94 44
# 10373       29              100.0     1               3978.51        981-443655
# 10386       43              100.0     4               5417.57    (91) 555 94 44
# 10397       34              62.24     1               2116.16        61.77.6555
# 10414       47              65.52     9               3079.44        6175559555
#
#                                                                ...   col_25  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    ...    STATE
# 10107       30              95.7      2               2871.0   ...       NY
# 10121       34              81.35     5               2765.9   ...  Unknown
# 10134       41              94.74     2               3884.34  ...  Unknown
# 10145       45              83.26     6               3746.7   ...       CA
# ...                                                            ...      ...
# 10350       20              100.0     15              2244.4   ...  Unknown
# 10373       29              100.0     1               3978.51  ...  Unknown
# 10386       43              100.0     4               5417.57  ...  Unknown
# 10397       34              62.24     1               2116.16  ...  Unknown
# 10414       47              65.52     9               3079.44  ...       MA
#
#                                                                      bvib  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    POSTALCODE
# 10107       30              95.7      2               2871.0        10022
# 10121       34              81.35     5               2765.9        51100
# 10134       41              94.74     2               3884.34       75508
# 10145       45              83.26     6               3746.7        90003
# ...                                                                   ...
# 10350       20              100.0     15              2244.4        28034
# 10373       29              100.0     1               3978.51       90110
# 10386       43              100.0     4               5417.57       28034
# 10397       34              62.24     1               2116.16       31000
# 10414       47              65.52     9               3079.44       51003
#
#                                                                  nbjib  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    COUNTRY
# 10107       30              95.7      2               2871.0       USA
# 10121       34              81.35     5               2765.9    France
# 10134       41              94.74     2               3884.34   France
# 10145       45              83.26     6               3746.7       USA
# ...                                                                ...
# 10350       20              100.0     15              2244.4     Spain
# 10373       29              100.0     1               3978.51  Finland
# 10386       43              100.0     4               5417.57    Spain
# 10397       34              62.24     1               2116.16   France
# 10414       47              65.52     9               3079.44      USA
#
#                                                                col_5_dup  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    TERRITORY
# 10107       30              95.7      2               2871.0     Unknown
# 10121       34              81.35     5               2765.9        EMEA
# 10134       41              94.74     2               3884.34       EMEA
# 10145       45              83.26     6               3746.7     Unknown
# ...                                                                  ...
# 10350       20              100.0     15              2244.4        EMEA
# 10373       29              100.0     1               3978.51       EMEA
# 10386       43              100.0     4               5417.57       EMEA
# 10397       34              62.24     1               2116.16       EMEA
# 10414       47              65.52     9               3079.44    Unknown
#
#                                                                          col_6  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    CONTACTLASTNAME
# 10107       30              95.7      2               2871.0                Yu
# 10121       34              81.35     5               2765.9           Henriot
# 10134       41              94.74     2               3884.34         Da Cunha
# 10145       45              83.26     6               3746.7             Young
# ...                                                                        ...
# 10350       20              100.0     15              2244.4            Freyre
# 10373       29              100.0     1               3978.51        Koskitalo
# 10386       43              100.0     4               5417.57           Freyre
# 10397       34              62.24     1               2116.16           Roulet
# 10414       47              65.52     9               3079.44          Yoshido
#
#                                                                          col_85  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    CONTACTFIRSTNAME
# 10107       30              95.7      2               2871.0               Kwai
# 10121       34              81.35     5               2765.9               Paul
# 10134       41              94.74     2               3884.34            Daniel
# 10145       45              83.26     6               3746.7              Julie
# ...                                                                         ...
# 10350       20              100.0     15              2244.4              Diego
# 10373       29              100.0     1               3978.51            Pirkko
# 10386       43              100.0     4               5417.57             Diego
# 10397       34              62.24     1               2116.16           Annette
# 10414       47              65.52     9               3079.44              Juri
#
#                                                               col_25_dup  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES     DEALSIZE
# 10107       30              95.7      2               2871.0       Small
# 10121       34              81.35     5               2765.9       Small
# 10134       41              94.74     2               3884.34     Medium
# 10145       45              83.26     6               3746.7      Medium
# ...                                                                  ...
# 10350       20              100.0     15              2244.4       Small
# 10373       29              100.0     1               3978.51     Medium
# 10386       43              100.0     4               5417.57     Medium
# 10397       34              62.24     1               2116.16      Small
# 10414       47              65.52     9               3079.44     Medium
#
#                                                                    col_52  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    ORDER_YEAR
# 10107       30              95.7      2               2871.0         2003
# 10121       34              81.35     5               2765.9         2003
# 10134       41              94.74     2               3884.34        2003
# 10145       45              83.26     6               3746.7         2003
# ...                                                                   ...
# 10350       20              100.0     15              2244.4         2004
# 10373       29              100.0     1               3978.51        2005
# 10386       43              100.0     4               5417.57        2005
# 10397       34              62.24     1               2116.16        2005
# 10414       47              65.52     9               3079.44        2005
#
#                                                                     col_65  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES    ORDER_MONTH
# 10107       30              95.7      2               2871.0             2
# 10121       34              81.35     5               2765.9             5
# 10134       41              94.74     2               3884.34            7
# 10145       45              83.26     6               3746.7             8
# ...                                                                    ...
# 10350       20              100.0     15              2244.4            12
# 10373       29              100.0     1               3978.51            1
# 10386       43              100.0     4               5417.57            3
# 10397       34              62.24     1               2116.16            3
# 10414       47              65.52     9               3079.44            5
#
#                                                               col_25_dup2
# ORDERNUMBER QUANTITYORDERED PRICEEACH ORDERLINENUMBER SALES     ORDER_DAY
# 10107       30              95.7      2               2871.0           24
# 10121       34              81.35     5               2765.9            7
# 10134       41              94.74     2               3884.34           1
# 10145       45              83.26     6               3746.7           25
# ...                                                                   ...
# 10350       20              100.0     15              2244.4            2
# 10373       29              100.0     1               3978.51          31
# 10386       43              100.0     4               5417.57           1
# 10397       34              62.24     1               2116.16          28
# 10414       47              65.52     9               3079.44           6
#
# [2824 rows x 23 columns]

# %%
# making N row header
read_file3 = pd.read_csv(r"C:\Users\HP\Downloads\sales_data.csv", header =2)

# %%
read_file3
# Out:
#       10121  34   81.35   5   2765.9  2003-05-07   Shipped  2  5.1  2003  ...  \
# 0     10134  41   94.74   2  3884.34  2003-07-01   Shipped  3    7  2003  ...
# 1     10145  45   83.26   6  3746.70  2003-08-25   Shipped  3    8  2003  ...
# 2     10159  49  100.00  14  5205.27  2003-10-10   Shipped  4   10  2003  ...
# 3     10168  36   96.66   1  3479.76  2003-10-28   Shipped  4   10  2003  ...
# 4     10180  29   86.13   9  2497.77  2003-11-11   Shipped  4   11  2003  ...
# ...     ...  ..     ...  ..      ...         ...       ... ..  ...   ...  ...
# 2816  10350  20  100.00  15  2244.40  2004-12-02   Shipped  4   12  2004  ...
# 2817  10373  29  100.00   1  3978.51  2005-01-31   Shipped  1    1  2005  ...
# 2818  10386  43  100.00   4  5417.57  2005-03-01  Resolved  1    3  2005  ...
# 2819  10397  34   62.24   1  2116.16  2005-03-28   Shipped  1    3  2005  ...
# 2820  10414  47   65.52   9  3079.44  2005-05-06   On Hold  2    5  2005  ...
#
#       Unknown  51100   France     EMEA    Henriot     Paul   Small 2003.1 5.2  \
# 0     Unknown  75508   France     EMEA   Da Cunha   Daniel  Medium   2003   7
# 1          CA  90003      USA  Unknown      Young    Julie  Medium   2003   8
# 2          CA  00000      USA  Unknown      Brown    Julie  Medium   2003  10
# 3          CA  94217      USA  Unknown     Hirano     Juri  Medium   2003  10
# 4     Unknown  59000   France     EMEA      Rance  Martine   Small   2003  11
# ...       ...    ...      ...      ...        ...      ...     ...    ...  ..
# 2816  Unknown  28034    Spain     EMEA     Freyre    Diego   Small   2004  12
# 2817  Unknown  90110  Finland     EMEA  Koskitalo   Pirkko  Medium   2005   1
# 2818  Unknown  28034    Spain     EMEA     Freyre    Diego  Medium   2005   3
# 2819  Unknown  31000   France     EMEA     Roulet  Annette   Small   2005   3
# 2820       MA  51003      USA  Unknown    Yoshido     Juri  Medium   2005   5
#
#        7
# 0      1
# 1     25
# 2     10
# 3     28
# 4     11
# ...   ..
# 2816   2
# 2817  31
# 2818   1
# 2819  28
# 2820   6
#
# [2821 rows x 28 columns]

# %%
pandas.read_json(path_or_buf, *, orient=None, typ='frame',
                 dtype=None, convert_axes=None, convert_dates=True,
                 keep_default_dates=True, precise_float=False, date_unit=None,
                 encoding=None, encoding_errors='strict', lines=False, chunksize=None, 
                 compression='infer', nrows=None, storage_options=None, 
                 dtype_backend=<no_default>, engine='ujson')

# %%
pandas.read_sql(sql, con, index_col=None, 
                coerce_float=True, params=None, 
                parse_dates=None, columns=None, 
                chunksize=None,
                dtype_backend=<no_default>, dtype=None)

# %% [markdown]
# Working with Duplicate Label

# %%
# You can check whether an Index (storing the row or column labels) is unique with Index.is_unique:
load_data.index.is_unique
# Out:
# True

# %%
load_data.columns.is_unique
# Out:
# True

# %%
load_data.index.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
# Disallowing Duplicate Labels
pd.DataFrame([[0, 1, 2], [3, 4, 5]], columns=["A", "B", "C"],).set_flags(
    allows_duplicate_labels=False)
# Out:
#    A  B  C
# 0  0  1  2
# 1  3  4  5

# %%
 deduplicated = load_data.groupby(level=0).first()  # remove duplicates
deduplicated.flags.allows_duplicate_labels = False  # disallow going forward

# %%
load_data
# Out:
#    First Name Last Name   Age         City Country                    Email  \
# 0        John       Doe  25.0     New York     USA     john.doe@example.com
# 1       Alice     Smith  30.0  Los Angeles     USA  alice.smith@example.com
# 2         Bob   Johnson  28.0      Chicago     USA                      NaN
# 3        John       Doe  25.0     New York     USA     john.doe@example.com
# 4     Charlie     Brown   NaN      Houston     USA    charlie.b@example.com
# 5       Emily     Davis  35.0      Phoenix     USA                      NaN
# 6       Frank    Miller  40.0          NaN     USA      frank.m@example.com
# 7       Grace    Wilson  27.0    San Diego     USA      grace.w@example.com
# 8        Hank    Taylor   NaN       Dallas     USA       hank.t@example.com
# 9         Ivy  Martinez  29.0     San Jose     USA                      NaN
# 10       John       Doe  25.0     New York     USA     john.doe@example.com
# 11      Alice     Smith  30.0  Los Angeles     USA  alice.smith@example.com
# 12        Bob   Johnson  28.0      Chicago     USA                      NaN
# 13       John       Doe  25.0     New York     USA     john.doe@example.com
# 14    Charlie     Brown   NaN      Houston     USA    charlie.b@example.com
# 15      Emily     Davis  35.0      Phoenix     USA                      NaN
# 16      Frank    Miller  40.0          NaN     USA      frank.m@example.com
# 17      Grace    Wilson  27.0    San Diego     USA      grace.w@example.com
# 18       Hank    Taylor   NaN       Dallas     USA       hank.t@example.com
# 19        Ivy  Martinez  29.0     San Jose     USA                      NaN
# 20       Jake       Lee  33.0          NaN     USA       jake.l@example.com
# 21       Kara     White  31.0       Austin     USA                      NaN
# 22        Leo     Black  37.0      Seattle     USA        leo.b@example.com
#
#            Phone   Salary
# 0   123-456-7890  50000.0
# 1   987-654-3210  60000.0
# 2   555-666-7777  55000.0
# 3            NaN  50000.0
# 4   222-333-4444  52000.0
# 5   111-222-3333      NaN
# 6   999-888-7777  70000.0
# 7            NaN  62000.0
# 8   777-888-9999  58000.0
# 9   666-555-4444  61000.0
# 10  123-456-7890  50000.0
# 11  987-654-3210  60000.0
# 12  555-666-7777  55000.0
# 13           NaN  50000.0
# 14  222-333-4444  52000.0
# 15  111-222-3333      NaN
# 16  999-888-7777  70000.0
# 17           NaN  62000.0
# 18  777-888-9999  58000.0
# 19  666-555-4444  61000.0
# 20  444-555-6666  59000.0
# 21  333-222-1111      NaN
# 22  888-777-6666  68000.0
